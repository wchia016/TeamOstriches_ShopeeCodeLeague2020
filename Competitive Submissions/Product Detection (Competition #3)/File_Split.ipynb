# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import random
from tqdm import tqdm
import shutil

cat = '41'
i = 1

# CHANGE THESE TO FIT YOUR FOLDER NAMES
full_folder = '/content/gdrive/My Drive/Shopee W2-4 Dataset/train/'
data_folder = os.path.join( full_folder, cat )

# %%
#os.listdir(data_folder)
files = os.listdir(data_folder)

# %%
for img in files:
  source = '/content/gdrive/My Drive/Shopee W2-4 Dataset/train/{}/{}'.format(cat,img)
  destination = '/content/gdrive/My Drive/Shopee W2-4 Dataset/train_{}/{}_{}/'.format(i,cat,i)
  dest = shutil.move(source, destination) 
  i+=1
  if i == 5:
    i=1
  else:
    continue
